# %%
import numpy as np

# %%
import os

# 1. 先检查当前工作目录
print("当前工作目录:", os.getcwd())

# 2. 检查目录是否存在
if os.path.exists("instance_time/50/rf-pomo/"):
    print("目录存在")
    # 列出该目录下的所有文件
    print("目录内容:", os.listdir("instance_time/50/rf-pomo/"))
else:
    print("目录不存在")

# 3. 检查文件是否存在
file_path = "instance_time/50/rf-pomo/cvrp.npz"
if os.path.exists(file_path):
    print(f"文件 {file_path} 存在")
    data = np.load(file_path)
    times = data["time"]
    print(times.shape)
else:
    print(f"文件 {file_path} 不存在")
# Out:
# 当前工作目录: /Users/chenxuxie/wfl_sw/routefinder
# 目录存在
# 目录内容: ['ovrpl.npz', 'vrpl.npz', 'vrpltw.npz', 'ovrpbltw.npz', 'ovrpltw.npz', 'ovrptw.npz', 'ovrpbl.npz', 'ovrpbtw.npz', 'vrpbtw.npz', 'vrpb.npz', 'vrpbl.npz', 'vrptw.npz', 'vrpbltw.npz', 'ovrpb.npz', 'cvrp.npz', 'ovrp.npz']
# 文件 instance_time/50/rf-pomo/cvrp.npz 存在
# (1000,)

# %%
data = np.load("instance_time/50/rf-pomo/cvrp.npz")

# %%
times = data["time"]
print(times.shape)
# Out:
# (1000,)

# %%
see_content(data, "time")
# Out:
# shape: (1000,)
# dtype: float32
# last 5 rows: [0.10007215 0.09870982 0.10033035 0.10052252 0.09888005]

# %%
data = np.load("instance_time/50/ortools/cvrp.npz")
see_content(data, "time")
# Out:
# shape: (1000,)
# dtype: float32
# last 5 rows: [10.015842 10.011211 10.019236 10.015558 10.017458]

# %%
def read(file_path):
    data = np.load(file_path)
    print("columns:", data.files)
    return data
def see_content(data, column_name):
    x = data[column_name]
    print("shape:", x.shape)
    print("dtype:", x.dtype)
    #print("first 5 rows:", x[:5])
    print("last 5 rows:", x[-5:])

# %%
fp="data/ovrpbltw/test/50.npz"
data = read(fp)
see_content(data, "open_route")
# Out:
# columns: ['locs', 'demand_linehaul', 'vehicle_capacity', 'speed', 'num_depots', 'demand_backhaul', 'backhaul_class', 'open_route', 'time_windows', 'service_time', 'distance_limit']
# shape: (1000, 1)
# dtype: bool
# last 5 rows: [[ True]
#  [ True]
#  [ True]
#  [ True]
#  [ True]]

# %%
see_content(data, "num_depots")
# Out:
# shape: (1000, 1)
# dtype: int32
# last 5 rows: [[1]
#  [1]
#  [1]
#  [1]
#  [1]]

# %%
fp="data/cvrp/test/50.npz"

# %%
data = read(fp)
# Out:
# columns: ['locs', 'demand_linehaul', 'vehicle_capacity', 'speed', 'num_depots']

# %%
see_content(data, "vehicle_capacity")
# Out:
# shape: (1000, 1)
# dtype: float32
# last 5 rows: [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]]

# %%
see_content(data, "speed")
# Out:
# shape: (1000, 1)
# dtype: float32
# last 5 rows: [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]]

# %%
see_content(data, "demand_linehaul")
# Out:
# shape: (1000, 50)
# dtype: float32
# last 5 rows: [[0.075 0.125 0.125 0.025 0.175 0.125 0.1   0.2   0.175 0.225 0.225 0.025
#   0.05  0.1   0.125 0.225 0.05  0.125 0.15  0.025 0.225 0.075 0.15  0.175
#   0.15  0.025 0.025 0.175 0.125 0.15  0.025 0.175 0.025 0.075 0.175 0.05
#   0.025 0.15  0.125 0.15  0.225 0.2   0.125 0.075 0.2   0.1   0.1   0.15
#   0.05  0.125]
#  [0.1   0.075 0.225 0.225 0.15  0.225 0.05  0.225 0.075 0.05  0.225 0.025
#   0.15  0.175 0.05  0.025 0.05  0.1   0.1   0.025 0.05  0.225 0.075 0.225
#   0.175 0.15  0.15  0.1   0.15  0.225 0.125 0.175 0.15  0.05  0.175 0.225
#   0.125 0.05  0.1   0.025 0.075 0.2   0.125 0.075 0.025 0.1   0.125 0.05
#   0.2   0.225]
#  [0.05  0.2   0.15  0.15  0.175 0.025 0.125 0.025 0.2   0.175 0.175 0.15
#   0.175 0.225 0.125 0.15  0.05  0.025 0.075 0.05  0.075 0.15  0.075 0.225
#   0.125 0.075 0.1   0.125 0.175 0.075 0.175 0.225 0.1   0.125 0.1   0.125
#   0.15  0.2   0.15  0.1   0.05  0.15  0.075 0.225 0.1   0.025 0.2   0.15
# ...

# %%
see_content(data, "num_depots")
# Out:
# shape: (1000, 1)
# dtype: int32
# last 5 rows: [[1]
#  [1]
#  [1]
#  [1]
#  [1]]

# %%
see_content(data, "locs")
# Out:
# shape: (1000, 51, 2)
# dtype: float32
# last 5 rows: [[[8.07517707e-01 1.70462310e-01]
#   [6.15778089e-01 4.08904731e-01]
#   [8.34081322e-02 5.42389005e-02]
#   [7.77241290e-01 1.49243325e-01]
#   [2.26002976e-01 4.23576981e-01]
#   [2.68000275e-01 5.31604886e-02]
#   [1.91486597e-01 2.04428479e-01]
#   [4.01756316e-01 2.27900848e-01]
#   [7.65876651e-01 5.27615190e-01]
#   [7.21859157e-01 3.61209065e-01]
#   [8.74608994e-01 6.91570401e-01]
#   [8.80603194e-01 2.71716058e-01]
#   [3.62241030e-01 5.93609035e-01]
#   [3.81953508e-01 2.21973717e-01]
#   [7.10577428e-01 6.92034900e-01]
#   [1.54122636e-01 4.97013330e-02]
#   [6.04889750e-01 4.70705360e-01]
#   [4.59379852e-01 7.01136589e-01]
#   [1.40531421e-01 5.75991690e-01]
#   [1.35375932e-01 6.55529797e-01]
#   [9.64751989e-02 8.47835004e-01]
#   [7.66742468e-01 5.67481965e-02]
#   [4.01662942e-03 9.28078175e-01]
#   [6.48803890e-01 7.44052768e-01]
#   [7.14529771e-04 7.60691285e-01]
#   [8.00898194e-01 4.97230172e-01]
# ...

# %%
data = np.load(fp)
see_content(data, "actions")
see_content(data, "costs")
# Out:
# shape: (1000, 113)
# dtype: int64
# last 5 rows: [[100  62  80  13   3  75  54  31  72  30   0  71  14  58  97  92  59  79
#    12   0  84  95  76   7  55  18  86  15  98  38   1  49   0   5  32  34
#    66  23  89  24  37  91  81  85  57   0  46  45  51  67  41  64  90  77
#    52  87  21  74   0  47  60  22  39  73  10  88   0  82  65  29  70   4
#    28  83   2  25  78   0   8  53  40  16  43  35  11  33  36   0  50   6
#    42  93  17  63  61  69   9   0  56  26  44  96  68  94  99  19  27   0
#    20  48   0   0   0]
#  [ 12  40  24  47   1  80   4  64  45  87  60  96  88  44   0  52  86  15
#    18  74  53  77  16  66   0  25  59  34  98  82  62  75  85  49   0  99
#    92  14  76  10  31  89  20  51   0  91  28  69  81  71  33  94  36   0
#     7  90  42  83   5   3  58  35  19  73  93  30   0  11   6   8  68  50
#    63  65  22  55   0  61  54   2  72  78 100  43  29   0  37  48  23  79
#    13  46  21  70  97  41   9  27   0  38  95  84  32  17  57  39  26  56
# ...

# %%
x = data["time"]#50_sol_pyvrp
print(x.shape)
print(x.dtype)
print(x)
# Out:
# (8000,)
# float32
# [0.00097079 0.00097079 0.00097079 ... 0.00097079 0.00097079 0.00097079]

# %%
data = np.load("data/cvrp/test/100_sol_pyvrp.npz")
print(data.files)
# Out:
# ['actions', 'costs', 'time']

# %%
see_content(data, "actions")
see_content(data, "costs")
# Out:
# shape: (1000, 112)
# dtype: int64
# last 5 rows: [[ 74  21  87  52  77  64  90  41  67  51  45  46   0  82  28   4  70  29
#    65  22  60  47   0  56  36  33   8  73  39  10  88   0  53  25   2  83
#    35  43  16  40  78  11   0  50   6  42  93  17  63  61  69  26  27   0
#    20   9  44  96  68  94  99  19  48   0  12  79  59  92  97  58  14  71
#     0 100  62  80  13   3  75  31  54  72  30   0  84  95  76  86   7  55
#    18  15  98  38   1  49   0   5  32  34  66  24  89  23  37  91  81  85
#    57   0   0   0]
#  [ 28  49  69  81  71  94  36  67   0  52  86  15  18  74  53  77  16  66
#     0   7  85  75  62  82  98  34  59  25  91   0  51  20  89  31  10  14
#    76  92  99   0  33  73  19  35  58   3   5  12  83   0  90  42  40  24
#    47   1  80   4  64  45  87  60  65  63  68  93   0  54  55  50   8   6
#    11  61   0  30  44  22  88 100  96  43  78  72   2   0  56  41  97  70
#    21  46  13  79  29  23  48  37   0  26  39  57  17  32   9  27  84  95
# ...

# %%
x = data["time"]#50_sol_pyvrp
print(x.shape)
print(x.dtype)
print(x)
# Out:
# ()
# float32
# 247.44447

# %%
x = data["costs"]#50_sol_pyvrp
print(x.shape)
print(x.dtype)
print(x[:5]) 
x = data["actions"]#50_sol_pyvrp
print(x.shape)
print(x.dtype)
print(x[:5]) 
x = data["time"]#50_sol_pyvrp
print(x.shape)
print(x.dtype)
print(x)
# Out:
# (1000,)
# float32
# [ -8.9    -9.821 -10.184 -10.263  -9.25 ]
# (1000, 59)
# int64
# [[44 42 16  2 15 35 17  6 13  0 11 39 20 34 32  8 26 36 31  5  0  7 38 47
#   22 40 10  0 19 46 27 43  9 28  4 29 12 41 50  0  1 48 33 18 37  3  0 30
#   14 24  0 25 49 21 23 45  0  0  0]
#  [46 21 13 16 25 34  0 10  0  7  4 11 41 47 44  0 15  6 17  1 22 23 43 32
#    0 40 27 48 33 30 49 31  8 24 20  0 38 26  9 50  5 35 37 42 28  0 39 14
#   18  2 19  3 45 36 29 12  0  0  0]
#  [34  8 18 38 20 37  1 19  0 28 10 33 12  2 11 15  0 32 36 41 30  0 25  4
#   49  6 40 27  0 46 35 48  7 14 44  9  0 43 21 13  3 22 26 29 23 16  0 17
#   42 47 24 39 50 45  5 31  0  0  0]
#  [14  4  3 11 48 33 43 12 24  0 39 23 36 27 37 34  0 46 21 50 28 18  9 42
#   26 10  2  0 31  1 15 19 41 16  7 32  8  0 47  6 29 35 44 17 25 22 49  0
#   38  5 45 13 20 30 40  0  0  0  0]
#  [26 43 17 34 39 11 47 19  0 23 46  2 44 21  0  5 22 12 50 18 13 29 30  0
#   38  6 10 27  3  1  0 24 36 32 31 48  9 37 40  0 35 42 28 14 45 41 49 33
# ...
